# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.feature_selection import mutual_info_regression

# %%
df = pd.read_csv(r"C:\Users\Simplon\Desktop\Travaux python\C02 Project\2016_Building_Energy_Benchmarking.csv", index_col = 'OSEBuildingID', thousands=",")

# %%
df = df.drop(columns={'Comments', 'Outlier'})
df = df.fillna(0)

# %%
df
# Out:
#                DataYear        BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 1                  2016      NonResidential               Hotel
# 2                  2016      NonResidential               Hotel
# 3                  2016      NonResidential               Hotel
# 5                  2016      NonResidential               Hotel
# 8                  2016      NonResidential               Hotel
# ...                 ...                 ...                 ...
# 50222              2016  Nonresidential COS              Office
# 50223              2016  Nonresidential COS               Other
# 50224              2016  Nonresidential COS               Other
# 50225              2016  Nonresidential COS  Mixed Use Property
# 50226              2016  Nonresidential COS  Mixed Use Property
#
#                                       PropertyName           Address     City  \
# OSEBuildingID
# 1                             Mayflower park hotel     405 Olive way  Seattle
# 2                                  Paramount Hotel   724 Pine street  Seattle
# 3                          5673-The Westin Seattle   1900 5th Avenue  Seattle
# 5                                        HOTEL MAX    620 STEWART ST  Seattle
# 8                      WARWICK SEATTLE HOTEL (ID8)     401 LENORA ST  Seattle
# ...                                            ...               ...      ...
# 50222                        Horticulture building  1600 S Dakota St  Seattle
# 50223          International district/Chinatown CC     719 8th Ave S  Seattle
# 50224                              Queen Anne Pool    1920 1st Ave W  Seattle
# 50225                  South Park Community Center    8319 8th Ave S  Seattle
# 50226                  Van Asselt Community Center  2820 S Myrtle St  Seattle
#
#               State  ZipCode TaxParcelIdentificationNumber  \
# OSEBuildingID
# 1                WA  98101.0                    0659000030
# 2                WA  98101.0                    0659000220
# 3                WA  98101.0                    0659000475
# 5                WA  98101.0                    0659000640
# 8                WA  98121.0                    0659000970
# ...             ...      ...                           ...
# 50222            WA      0.0                    1624049080
# 50223            WA      0.0                    3558300000
# 50224            WA      0.0                    1794501150
# 50225            WA      0.0                    7883603155
# 50226            WA      0.0                    7857002030
#
#                CouncilDistrictCode  ... SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# OSEBuildingID                       ...
# 1                                7  ...          7.456910e+06      2003882.00
# 2                                7  ...          8.664479e+06            0.00
# 3                                7  ...          7.393711e+07     21566554.00
# 5                                7  ...          6.946800e+06      2214446.25
# 8                                7  ...          1.465650e+07            0.00
# ...                            ...  ...                   ...             ...
# 50222                            2  ...          9.430032e+05            0.00
# 50223                            2  ...          1.053706e+06            0.00
# 50224                            7  ...          6.053764e+06            0.00
# 50225                            1  ...          7.828413e+05            0.00
# 50226                            2  ...          1.293722e+06            0.00
#
#                Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# OSEBuildingID
# 1                  1.156514e+06       3.946027e+06        12764.529300
# 2                  9.504252e+05       3.242851e+06        51450.816410
# 3                  1.451544e+07       4.952666e+07        14938.000000
# 5                  8.115253e+05       2.768924e+06        18112.130860
# 8                  1.573449e+06       5.368607e+06        88039.984380
# ...                         ...                ...                 ...
# 50222              1.536550e+05       5.242709e+05         3254.750244
# 50223              1.162210e+05       3.965461e+05         5537.299805
# 50224              5.252517e+05       1.792159e+06        39737.390630
# 50225              1.022480e+05       3.488702e+05         3706.010010
# 50226              1.267744e+05       4.325542e+05         7203.419922
#
#                NaturalGas(kBtu)  DefaultData              ComplianceStatus  \
# OSEBuildingID
# 1                  1.276453e+06        False                     Compliant
# 2                  5.145082e+06        False                     Compliant
# 3                  1.493800e+06        False                     Compliant
# 5                  1.811213e+06        False                     Compliant
# 8                  8.803998e+06        False                     Compliant
# ...                         ...          ...                           ...
# 50222              3.254750e+05         True  Error - Correct Default Data
# 50223              5.537300e+05        False                     Compliant
# 50224              3.973739e+06        False                     Compliant
# 50225              3.706010e+05        False                     Compliant
# 50226              7.203420e+05        False                     Compliant
#
#                TotalGHGEmissions GHGEmissionsIntensity
# OSEBuildingID
# 1                         249.98                  2.83
# 2                         295.86                  2.86
# 3                        2089.28                  2.19
# 5                         286.43                  4.67
# 8                         505.01                  2.88
# ...                          ...                   ...
# 50222                      20.94                  1.70
# 50223                      32.17                  2.01
# 50224                     223.54                 16.99
# 50225                      22.11                  1.57
# 50226                      41.27                  2.26
#
# [3376 rows x 43 columns]

# %% [markdown]
# ## Fonction pour le mutual information

# %%
def make_mi_scores(X, y):
    X = X.copy()
    for colname in X.select_dtypes(["object", "category"]):
        X[colname], _ = X[colname].factorize()
    # All discrete features should now have integer dtypes
    discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")

# %% [markdown]
# ## Mutual Information / No encoding

# %%
X = df.copy()
y = X.pop("TotalGHGEmissions")

# %%
mi_scores = make_mi_scores(X, y)

# %%
plt.figure(dpi=100, figsize=(8, 10))
plot_mi_scores(mi_scores)
